# %%
# %matplotlib inline
from cf import CF
import matplotlib.pyplot as plt

# %%
cf = CF('../merge/whole_month.data', preprocess=['mean','log10'])
cf.MDS(link=True, val=1)

# %%
cf = CF('../merge/whole_month.data', preprocess=[])
cf.MDS(link=True, val=1)
