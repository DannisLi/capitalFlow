# %%
# %matplotlib inline
from cf import CF
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


items = [
    'a', 'ag', 'al', 'au', 'b', 'bb', 'bu', 'c', 'cf', 'cu', 'fb', 'fg', 'fu', 'i', 'j', 'jd', 
    'jm', 'jr', 'l', 'm', 'oi', 'p', 'pb', 'pm', 'rb', 'ri', 'rm', 'rs', 'ru', 'sr', 'ta', 'v', 
    'wh', 'wr', 'y', 'zn', 'fund'
]

item2name = {
    'a': '豆一', 'ag': '沪银', 'al': '沪铝', 'au': '沪金', 'b': '豆二', 'bb': '胶合板', 'bu': '沥青', 'c': '玉米', 'cf': '郑棉', 
    'cu': '沪铜', 'fb': '纤维板', 'fg': '玻璃', 'fu': '燃油', 'i': '铁矿石', 'j': '焦炭', 'jd': '鸡蛋', 'jm': '焦煤', 'jr': '粳稻', 
    'l': '塑料', 'm': '豆粕', 'oi': '菜油', 'p': '棕榈油', 'pb': '沪铅', 'pm': '普麦', 'rb': '螺纹钢', 'ri': '早籼稻', 'rm': '菜粕', 
    'rs': '菜籽', 'ru': '橡胶', 'sr': '白糖', 'ta': 'PTA', 'v': 'PVC', 'wh': '强麦', 'wr': '线材', 'y': '豆油', 'zn': '沪锌', 'fund': 'fund'
}


I,J,K = 7,7,2
M,N = 37,36
# Out:
# /home/lizimeng/python/lib/python3.6/site-packages/IPython/nbformat.py:13: ShimWarning: The `IPython.nbformat` package has been deprecated since IPython 4.0. You should import from nbformat instead.
#   "You should import from nbformat instead.", ShimWarning)

# %%
cf = CF('../merge/whole_month.data', ['log10'])
res = cf.series_tucker([I,J,K], [1.,1.,1.,1.], 6)
for r in res:
    r.energy_norm()
    print (r.RRMSE, r.sparseness)
# Out:
# Starting MATLAB on ZMQ socket ipc:///tmp/pymatbridge-52beadc3-e231-4744-8052-7b988e65c85b
# Send 'exit' command to kill the server
# ...MATLAB started and connected!
# MATLAB closed
# Starting MATLAB on ZMQ socket ipc:///tmp/pymatbridge-b81fa9b1-14f9-4b78-a4d4-7f051b927703
# Send 'exit' command to kill the server
# ...MATLAB started and connected!
# MATLAB closed
# Starting MATLAB on ZMQ socket ipc:///tmp/pymatbridge-c5781d50-4af8-481c-912f-620494589c74
# Send 'exit' command to kill the server
# ...MATLAB started and connected!
# MATLAB closed
# Starting MATLAB on ZMQ socket ipc:///tmp/pymatbridge-457106e8-f78f-4acc-b072-aa6637791dce
# Send 'exit' command to kill the server
# ...MATLAB started and connected!
# MATLAB closed
# Starting MATLAB on ZMQ socket ipc:///tmp/pymatbridge-6092b192-8a16-437b-9884-4af514a1c05d
# Send 'exit' command to kill the server
# ....MATLAB started and connected!
# MATLAB closed
# Starting MATLAB on ZMQ socket ipc:///tmp/pymatbridge-aed38881-f0c7-4783-a053-4112cfd9683a
# Send 'exit' command to kill the server
# ....MATLAB started and connected!
# MATLAB closed
# 0.287388038102 (0.50258852294470757, 0.48675205602889449, 0.2868474785533901, 0.61000656845421564)
# 0.239961313263 (0.54611389790857534, 0.55435811088451104, 0.29945213810600319, 0.76427976386289065)
# 0.297200179116 (0.54495726136916001, 0.5357063243207717, 0.28930707112063325, 0.61912207711294809)
# 0.267092440932 (0.46789894703888341, 0.48593684684585231, 0.37683288850079577, 0.6766782258565377)
# 0.21974826756 (0.56437132258849854, 0.54680723816662014, 0.36547930233663978, 0.89904192367759261)
# 0.209674476328 (0.54101119272788833, 0.53927198201304483, 0.32441494715725855, 0.9344064973623345)

# %%
for r in res:
    r.T_analysis()

# %%
for r in res:
    for i in range()
    print (r.O_analysis())
    print ()
# Out:
# [['豆一', '豆二', '玉米', '燃油', '豆粕', '强麦', '线材'], ['沥青'], ['fund'], ['菜籽', 'PVC'], ['沪铅', '普麦'], ['粳稻', '早籼稻'], ['沪银', '沪铝', '沪金', '胶合板', '郑棉', '沪铜', '纤维板', '玻璃', '铁矿石', '焦炭', '鸡蛋', '焦煤', '塑料', '菜油', '棕榈油', '螺纹钢', '菜粕', '橡胶', '白糖', 'PTA', '豆油', '沪锌']]
#
# [['豆一', '沪银', '沪铝', '沪金', '胶合板', '玉米', '郑棉', '沪铜', '纤维板', '玻璃', '燃油', '铁矿石', '焦炭', '鸡蛋', '焦煤', '粳稻', '塑料', '豆粕', '菜油', '棕榈油', '普麦', '螺纹钢', '菜粕', '橡胶', '白糖', 'PTA', '线材', '豆油', '沪锌'], ['fund'], ['强麦'], ['早籼稻'], ['豆二', 'PVC'], ['沪铅'], ['沥青', '菜籽']]
#
# [['豆一', '沪银', '沪铝', '沪金', '豆二', '玉米', '郑棉', '沪铜', '玻璃', '铁矿石', '焦炭', '鸡蛋', '焦煤', '粳稻', '塑料', '豆粕', '菜油', '棕榈油', '普麦', '螺纹钢', '菜粕', '橡胶', '白糖', 'PTA', '线材', '豆油', '沪锌'], ['fund'], ['沥青', '菜籽'], ['早籼稻', '强麦'], ['燃油', 'PVC'], ['沪铅'], ['胶合板', '纤维板']]
#
# [['豆一', '沪银', '沪铝', '沪金', '豆二', '沥青', '玉米', '郑棉', '沪铜', '玻璃', '铁矿石', '鸡蛋', '粳稻', '塑料', '豆粕', '棕榈油', '普麦', '螺纹钢', '菜粕', '橡胶', '白糖', 'PTA', '线材', '豆油', '沪锌'], ['fund'], ['胶合板', '纤维板', '燃油', '早籼稻', '菜籽'], ['强麦'], ['沪铅'], ['PVC'], ['焦炭', '焦煤', '菜油']]
#
# [['豆一', '沪银', '沪铝', '沪金', '豆二', '胶合板', '沥青', '玉米', '郑棉', '沪铜', '纤维板', '玻璃', '燃油', '铁矿石', '焦炭', '鸡蛋', '焦煤', '粳稻', '塑料', '豆粕', '菜油', '棕榈油', '普麦', '螺纹钢', '早籼稻', '菜粕', '橡胶', '白糖', 'PTA', '线材', '豆油', '沪锌'], ['fund'], ['沪铅'], ['强麦'], ['PVC'], ['菜籽'], []]
#
# [['豆一', '沪银', '沪铝', '沪金', '豆二', '沥青', '玉米', '郑棉', '沪铜', '纤维板', '玻璃', '燃油', '铁矿石', '焦炭', '鸡蛋', '焦煤', '粳稻', '塑料', '豆粕', '菜油', '棕榈油', '螺纹钢', '早籼稻', '菜粕', '橡胶', '白糖', 'PTA', '线材', '豆油', '沪锌'], ['fund'], ['菜籽', '强麦'], [], ['沪铅'], ['PVC'], ['胶合板', '普麦']]

# %%
for r in res:
    print (r.D_analysis())
    print ()
# Out:
# [['豆一', '豆二', '玉米', '燃油', '强麦', '线材'], ['fund'], ['沥青'], ['沪铅', '普麦'], ['粳稻', '早籼稻'], ['菜籽', 'PVC'], ['沪银', '沪铝', '沪金', '胶合板', '郑棉', '沪铜', '纤维板', '玻璃', '铁矿石', '焦炭', '鸡蛋', '焦煤', '塑料', '豆粕', '菜油', '棕榈油', '螺纹钢', '菜粕', '橡胶', '白糖', 'PTA', '豆油', '沪锌']]
#
# [['豆一', '沪银', '沪铝', '沪金', '胶合板', '玉米', '郑棉', '沪铜', '纤维板', '玻璃', '燃油', '铁矿石', '焦炭', '鸡蛋', '焦煤', '粳稻', '塑料', '豆粕', '菜油', '棕榈油', '普麦', '螺纹钢', '菜粕', '橡胶', '白糖', 'PTA', '线材', '豆油', '沪锌'], ['fund'], ['豆二', 'PVC'], ['沥青', '菜籽'], ['强麦'], ['沪铅'], ['早籼稻']]
#
# [['豆一', '沪银', '沪铝', '沪金', '豆二', '玉米', '郑棉', '沪铜', '玻璃', '铁矿石', '焦炭', '鸡蛋', '焦煤', '粳稻', '塑料', '豆粕', '菜油', '棕榈油', '普麦', '螺纹钢', '菜粕', '橡胶', '白糖', 'PTA', '线材', '豆油', '沪锌'], ['fund'], ['燃油', '早籼稻', '强麦'], ['沥青', '菜籽'], ['PVC'], ['胶合板', '纤维板'], ['沪铅']]
#
# [['豆一', '沪银', '沪铝', '沪金', '豆二', '玉米', '郑棉', '沪铜', '玻璃', '鸡蛋', '粳稻', '塑料', '普麦', '螺纹钢', '橡胶', '白糖', 'PTA', '线材', '沪锌'], ['fund'], ['胶合板', '纤维板', '早籼稻', '菜籽'], ['沪铅'], ['强麦'], ['燃油', 'PVC'], ['沥青', '铁矿石', '焦炭', '焦煤', '豆粕', '菜油', '棕榈油', '菜粕', '豆油']]
#
# [['豆一', '沪银', '沪铝', '沪金', '豆二', '胶合板', '沥青', '玉米', '郑棉', '沪铜', '纤维板', '玻璃', '燃油', '铁矿石', '焦炭', '鸡蛋', '焦煤', '粳稻', '塑料', '豆粕', '菜油', '棕榈油', '普麦', '螺纹钢', '早籼稻', '菜粕', '橡胶', '白糖', 'PTA', '线材', '豆油', '沪锌'], ['fund'], ['沪铅'], ['强麦'], ['PVC'], ['菜籽'], []]
#
# [['豆二', '纤维板', '燃油', '粳稻', '早籼稻', 'PVC', '线材'], ['fund'], ['菜籽', '强麦'], ['沪铅'], [], ['豆一', '沪银', '沪铝', '沪金', '沥青', '玉米', '郑棉', '沪铜', '玻璃', '铁矿石', '焦炭', '鸡蛋', '焦煤', '塑料', '豆粕', '菜油', '棕榈油', '螺纹钢', '菜粕', '橡胶', '白糖', 'PTA', '豆油', '沪锌'], ['胶合板', '普麦']]
